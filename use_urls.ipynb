# %%
import json

# %%
fd = open('./data/project_live_meta.json', 'r')
text = fd.read()
fd.close()

# %%
pmeta = json.loads(text)

# %%
pmeta[0].keys()
# Out:
# [u'category',
#  u'goal',
#  u'author',
#  u'url',
#  u'pledged',
#  u'spotlight',
#  u'currency',
#  u'state',
#  u'deadline',
#  u'location',
#  u'backers_count',
#  u'id',
#  u'launched_at',
#  u'blurb',
#  u'name']

# %%
url_list = [p["url"] for p in pmeta]
url_list
# Out:
# [u'https://www.kickstarter.com/projects/1072524368/the-muse-arts-productions-debut-the-last-five-year/description',
#  u'https://www.kickstarter.com/projects/1313202768/wakedestination-pendants/description',
#  u'https://www.kickstarter.com/projects/striveforth/a-terrible-tearable-book/description',
#  u'https://www.kickstarter.com/projects/850255516/couples-pregnancy-massage-ebook-and-print-book/description',
#  u'https://www.kickstarter.com/projects/2005672774/simply-delish/description',
#  u'https://www.kickstarter.com/projects/intothesea/peter-sus-debut-album-into-the-sea/description',
#  u'https://www.kickstarter.com/projects/598593213/naked-filter-clean-water-for-every-body/description',
#  u'https://www.kickstarter.com/projects/idiedwhatever/i-died-i-came-back-whatever/description',
#  u'https://www.kickstarter.com/projects/1451143980/the-queen-of-elfland/description',
# ...
