# %%
import kickass as ks

import json
fd = open("../data/project_successful_final_tech_sample.json", "r")

project_json = json.load(fd)

ks_projects = ks.ProjectCollection(project_json, "../data/stopwords.txt")

# %%
D, s, T = ks_projects.svd(1)

# %%
print ks.np.shape(D), ks.np.shape(s), ks.np.shape(T)
# Out:
# (100, 100) (100,) (1899, 1899)

# %%
var = ks.np.cumsum(s ** 2) / sum(s ** 2)

# %%
import matplotlib.pyplot as plt
plt.plot(var)
plt.ylabel('some numbers')
plt.grid(True)
plt.show()

# %%
plt.plot(s)
plt.ylabel('some numbers')
plt.grid(True)
plt.show()

# %%
S = ks.np.zeros((ks.np.shape(D)[0], ks.np.shape(T)[0]))
print(ks.np.shape(D), ks.np.shape(S), ks.np.shape(T))
# Out:
# ((100, 100), (100, 1899), (1899, 1899))

# %%
yo = ks_projects.latent_doc_term_mat(50)
ks.np.shape(yo)
# Out:
# (50, 100) (50, 50) (50, 1899)
# ()

# %%
X = ks.np.array([[10,5,0,0,1,0], [0,5,14,2,0,0], [1,1,0,10,20,2], [0,1,0,5,21,7]])
U, s, V = ks.np.linalg.svd(X, full_matrices=True)
# Out:
# array([ 31.61134138,  15.14937959,  10.90178367,   5.03691446])

# %%
Ud = U[:2]
sd = s[:2]
Vd = V[:2]
print(ks.np.shape(Ud), ks.np.shape(sd), ks.np.shape(Vd))
# Out:
# ((2, 4), (2,), (2, 6))
# [ 31.61134138  15.14937959]

# %%
S = ks.np.array(ks.np.shape(Ud)[0], ks.np.shape(Vd)[0])
print ks.np.dot(Ud.T, ks.np.dot(S, Vd))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-4cf65958a789> in <module>()
# ----> 1 S = ks.np.array(ks.np.shape(Ud)[0], ks.np.shape(Vd)[0])
#       2 print ks.np.dot(Ud.T, ks.np.dot(S, Vd))
#
# TypeError: data type not understood

# %%
ks.np.shape(V)
# Out:
# (6, 6)

# %%
a = ks.np.random.randn(9, 6) + 1j*ks.np.random.randn(9, 6)
U, s, V = ks.np.linalg.svd(a, full_matrices=True)
print(U.shape, V.shape, s.shape)
S = ks.np.zeros((9, 6), dtype=complex)
S[:6, :6] = ks.np.diag(s)
ks.np.dot(U, ks.np.dot(S, V))
