# %% [markdown]
# #1

# %% [markdown]
# ### Set up data and create a object of class ProjectCollection

# %%
import kickass as ks
import matplotlib.pyplot as plt
import json

#pull 100 projects from 4 categories
project_amalgam = []
file = lambda cat: ("../data/project_successful_details_"+cat+"_sample.json")
categories = ['art', 'crafts','design', 'photography' ]

for cat in categories:
    
    fd = open(file(cat), "r")
    
    project_json = json.load(fd)

    project_amalgam = project_amalgam + project_json[0:100]

# %%
#create project collection class
ks_projects = ks.ProjectCollection(project_amalgam, "../data/stopwords.txt")

# %% [markdown]
# ### Visualize the singular values and variances to judge a suitable cut off

# %%
#use te lsa function with cutoff parameter 1 to return an svd decomposition of the document term matrix
doc_id, D, s, T = ks_projects.lsa(1)

# %%
# calculate variance explained 
var = ks.np.cumsum(s ** 2) / sum(s ** 2)

# %%
#Draw plots showing variance explained and singular values respectively
plt.subplot(211)
plt.plot(var, linewidth=2.0)
plt.ylabel('% Variance', fontsize = 15)
plt.xlabel('Singular Value Index', fontsize = 15)
plt.title('Percentage Variance Explained', fontsize = 18)
x = range(0, len(var), 20)
plt.xticks(x, rotation='vertical')
plt.grid(True)
plt.show()

plt.subplot(212)
plt.plot(s, linewidth=2.0)
plt.ylabel('Singular Values', fontsize = 15)
plt.xlabel('Singular Value Index', fontsize = 15)
plt.title('Singular Values of the Project Corpus', fontsize = 18)
x = range(0, len(var), 20)
plt.xticks(x, rotation='vertical')
plt.grid(True)
plt.show()

# %% [markdown]
# Lets pick cutoff atf 60% variance explained. We can choose the cutoff parameter of our function that returns a document term matrix to be either .6 or roughly the top 100 singular values from the variance explained plot.

# %% [markdown]
# ### Calculate a document term matrix based on LSA and without LSA

# %%
doc_id, doc_term_mat_LSA = ks_projects.latent_doc_term_mat(.6)
doc_id1, doc_term_mat = ks_projects.doc_term_mat()

# %% [markdown]
# ### Calculate Cosine similarity of both Doc Term Matrices

# %%
doc_term_cosine = ks_projects.cosine_sim(doc_term_mat)
doc_term_cosine_LSA = ks_projects.cosine_sim(doc_term_mat_LSA)
# Out:
# kickass.py:203: RuntimeWarning: invalid value encountered in divide
#   return  (mat / norm[:,None])

# %% [markdown]
# ### Compare documents pre and post LSA to see the differences in document similarity

# %% [markdown]
# Cosine similarity of documents using a document term matrix may suffer from the following problems:
#
# 1. The matrix may be too <b>noisy</b> i.e components which do not contribute in "defining" a document.
# 2. The matrix lists only the words actually in each document, whereas we might be interested in all words related to each document—generally a much larger set due to <b>synonymy</b>.
# 3. The matrix also suffers from <b>polysemy</b> i.e each word may have different meanings
#
# Thus we expect the cosine similarity over such a matrix to be less representative of the <b>true</b> similarity between documents.
#
# Thus we estimate a <b>lower ranked approximation</b> of the document term matrix which we hope will mitigate the above stated problems and return a much better representation of cosine similarity between documents.

# %% [markdown]
# ### Cosine Similarity : Document Term Matrix without LSA

# %%
def heatmap(cosine_similarity):
    heatmap = plt.imshow(cosine_similarity)
    heatmap.set_cmap('PiYG')
    plt.colorbar()
    plt.show()

# %%
heatmap(doc_term_cosine)

# %% [markdown]
# Due to the problems discussed above, it would seem that all 400 projects show little or no similarity to each other with cosine similarity. We know for sure that that is not the case. The pair of white lines that also generate the "division" warning is due to the fact that one of the documents was empty and had no tokens.

# %% [markdown]
# ### Cosine Similarity : Document Term Matrix with LSA

# %%
heatmap(doc_term_cosine_LSA)

# %% [markdown]
# The heat map with the cosine similarity matrix after LSA throws up a much higher contrast and shows higher similarity accross documents. Having said that is not very informative at first glance. Lets try to reorder the matrix based on the categories of projects

# %% [markdown]
# ### Heat map after reordering the matrix

# %%
proj_cat =  [[doc.pid, doc.category_desc] for doc in ks_projects.docs]
for xid, did in enumerate(doc_id1):
    for proj in proj_cat:
        if did == proj[0]:
            proj.append(xid)
            
proj_cat_ind = [cat[2] for cat in proj_cat]
rearranged_LSA_doc_term_cosine = ks_projects.cosine_sim(doc_term_mat_LSA[proj_cat_ind ])

# %%
heatmap(rearranged_LSA_doc_term_cosine)

# %% [markdown]
# Although not very noticable but it is possible to observe a "light" "clustering of documents" from the intervals [0, 100), [100, 200), [200, 300), [300, 400). These intervals correspond to the categories "art", "crafts", "design", "photography". The last cluster of photograpy shows the maximum similarity among documents as, intutively speaking, the topic "photography" is much more specific than the topic "art", "crafts" and "design" which are very broad by themselves.
